# %% [markdown]
# Install Kaggle

# %%
# !pip install kaggle

# %% [markdown]
# Mount Google Drive to Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Create a directory to store Kaggle API credentials and import necessary libraries for dataset handling:

# %%
# !mkdir ~/.kaggle

# %%
# !cp /content/kaggle.json

# %% [markdown]
# Download and extract the Fall Detection Dataset from Kaggle, then list its contents:

# %%
import os
import zipfile

# Set up Kaggle API credentials
os.environ['KAGGLE_CONFIG_DIR'] = '/content/kaggle.json'

# Download the dataset from Kaggle
# !kaggle datasets download -d uttejkumarkandagatla/fall-detection-dataset

# Unzip the downloaded dataset
with zipfile.ZipFile('fall-detection-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/fall_detection_dataset')

# List the contents of the extracted dataset
# !ls /content/fall_detection_dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uttejkumarkandagatla/fall-detection-dataset
# License(s): ODbL-1.0
# ...
#  82% 41.0M/49.7M [00:00<00:00, 60.3MB/s]
# 100% 49.7M/49.7M [00:00<00:00, 69.0MB/s]
# fall_dataset

# %% [markdown]
#  Remove any existing YOLOv5

# %%
# !rm -rf yolov5/yolov5

# %% [markdown]
#  Clone the official YOLOv5 repository

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16953, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 16953 (delta 75), reused 99 (delta 49), pack-reused 16805 (from 1)
# Receiving objects: 100% (16953/16953), 15.70 MiB | 17.32 MiB/s, done.
# Resolving deltas: 100% (11604/11604), done.
# /content/yolov5

# %%
# Navigate to the YOLOv5 directory
# %cd /content/yolov5

# Uninstall conflicting requests version
# !pip uninstall -y requests

# Install the required requests version
# !pip install requests==2.31.0

# Install YOLOv5 dependencies
# !pip install -qr requirements.txt

# Verify installed packages
# !pip list
# Out:
# /content/yolov5
# Found existing installation: requests 2.32.3
# Uninstalling requests-2.32.3:
#   Successfully uninstalled requests-2.32.3
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 2.3 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.31.0 which is incompatible.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 56.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.8/871.8 kB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.1 MB/s eta 0:00:00
# Package                          Version
# ...

# %%
# !pip install requests==2.31.0
# Out:
# ...
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# ...
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# ...

# %%
# !pip install requests==2.32.3

# %% [markdown]
#  Unzip and verify

# %%
# import zipfile

# # Unzip the downloaded dataset
# with zipfile.ZipFile('fall-detection-dataset.zip', 'r') as zip_ref:
#     zip_ref.extractall('/content/fall_detection_dataset')

# # List the contents to verify extraction
# !ls /content/fall_detection_dataset

# %% [markdown]
# Configure dataset paths

# %%
data_yaml = """\
train: /content/fall_detection_dataset/fall_dataset/images/train
val: /content/fall_detection_dataset/fall_dataset/images/val
nc: 3 # number of classes
names: ['Fall Detected', 'Walking', 'Sitting'] # class names
"""

with open('/content/yolov5/fall_detection.yaml', 'w') as file:
    file.write(data_yaml)

# %% [markdown]
# Train YOLOv5 model

# %%
# !python train.py --data /content/yolov5/fall_detection.yaml --weights yolov5s.pt --epochs 5 --batch-size 20 --imgsz 640
# Out:
# 2024-09-10 07:31:52.101072: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-10 07:31:52.126864: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-10 07:31:52.134197: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# List directories in /content/yolov5/runs/train/
# !ls /content/yolov5/runs/train/
# Out:
# exp

# %%
# List contents of the first experiment directory
# !ls /content/yolov5/runs/train/exp/weights/
# Out:
# best.pt  last.pt

# %%
# List contents of the second experiment directory
# !ls /content/yolov5/runs/train/exp2/weights/
# Out:
# ls: cannot access '/content/yolov5/runs/train/exp2/weights/': No such file or directory

# %% [markdown]
# Validate YOLOv5 model.

# %%
# !python val.py --img 640 --batch 20 --data /content/yolov5/fall_detection.yaml --weights /content/yolov5/runs/train/exp2/weights/best.pt
# Out:
# val: data=/content/yolov5/fall_detection.yaml, weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], batch_size=20, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-365-g12b577c8 Python-3.10.12 torch-2.4.0+cu121 CPU
#
# Traceback (most recent call last):
#   File "/content/yolov5/val.py", line 604, in <module>
#     main(opt)
#   File "/content/yolov5/val.py", line 575, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/yolov5/val.py", line 270, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
# ...

# %%
# List the contents of the train directory
# !ls /content/yolov5/runs/train/
# Out:
# exp

# %%
# List the contents of the validation directory
# !ls /content/yolov5/runs/val/
# Out:
# exp

# %% [markdown]
# Clean up old experiments

# %%
import os
import shutil

# Define paths to the train and validation directories
train_dir = '/content/yolov5/runs/train'
val_dir = '/content/yolov5/runs/val'

# Specify the directories to keep
keep_train = ['exp2']
keep_val = ['exp7']

def delete_old_experiments(base_dir, keep_dirs):
    # Get a list of all subdirectories
    subdirs = [os.path.join(base_dir, d) for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))]

    # Iterate over all directories
    for subdir in subdirs:
        # Get the directory name
        dirname = os.path.basename(subdir)

        # Check if the directory should be kept
        if dirname not in keep_dirs:
            print(f"Deleting {subdir}")
            shutil.rmtree(subdir)

# Delete old experiments in train directory, keeping exp2
delete_old_experiments(train_dir, keep_train)

# Delete old experiments in validation directory, keeping exp7
delete_old_experiments(val_dir, keep_val)
# Out:
# Deleting /content/yolov5/runs/train/exp
# Deleting /content/yolov5/runs/val/exp

# %% [markdown]
# Test model on video

# %%
import cv2
import torch

# Define paths
weights_path = '/content/yolov5/runs/train/exp/weights/best.pt'  # Path to your trained model weights
video_path = '/content/Human.mp4'  # Path to your input video
output_path = 'output_video.mp4'  # Path to save the output video

# Load YOLOv5 model
model = torch.hub.load('/content/yolov5', 'custom', path=weights_path, source='local')
model.eval()

# Open video file
cap = cv2.VideoCapture(video_path)
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for .mp4 files
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Perform inference
    results = model(frame)
    labels, cords = results.xyxyn[0][:, -1], results.xyxyn[0][:, :-1]

    # Draw bounding boxes and labels
    for i, (label, cord) in enumerate(zip(labels, cords)):
        x1, y1, x2, y2, conf = cord
        x1, y1, x2, y2 = int(x1 * width), int(y1 * height), int(x2 * width), int(y2 * height)

        # Draw bounding box
        color = (0, 0, 255) if label == 0 else (0, 255, 0)  # Red for falling, green for other classes
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)

        # Put label text
        label_text = f'Class {int(label)}: {conf:.2f}'
        cv2.putText(frame, label_text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

    # Write frame to output video
    out.write(frame)

# Release everything
cap.release()
out.release()
cv2.destroyAllWindows()

print(f'Output video saved at {output_path}')

# %%
from google.colab import files
files.download('output_video.mp4')
